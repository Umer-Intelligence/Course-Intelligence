# %%
#In this file we are going to analyze the 'course' dataset using Pyhton

# %% [markdown]
# #  Loading necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Viewing dataset

# %%
Course = pd.read_excel('C:/Desktop/Courses/Course.xlsx')
Course.head()
# Out:
#   Institution Course Number          Launch Date  \
# 0        MITx        6.002x  2012-05-09 00:00:00
# 1        MITx         6.00x           09/26/2012
# 2        MITx        3.091x  2012-09-10 00:00:00
# 3    HarvardX         CS50x           10/15/2012
# 4    HarvardX        PH207x           10/15/2012
#
#                                         Course Title  \
# 0                           Circuits and Electronics
# 1   Introduction to Computer Science and Programming
# 2              Introduction to Solid State Chemistry
# 3                   Introduction to Computer Science
# 4  Health in Numbers: Quantitative Methods in Cli...
#
#                                          Instructors  \
# 0                                     Khurram Afridi
# 1            Eric Grimson, John Guttag, Chris Terman
# 2                                       Michael Cima
# 3  David Malan, Nate Hardison, Rob Bowden, Tommy ...
# 4                 Earl Francis Cook, Marcello Pagano
#
# ...

# %% [markdown]
# #  Analysing dataset

# %%
#To find the number of courses of each subject

# %%
Course.groupby('Course Subject')['Course Subject'].count()
# Out:
# Course Subject
# Computer Science                                        30
# Government, Health, and Social Science                  75
# Humanities, History, Design, Religion, and Education    94
# Science, Technology, Engineering, and Mathematics       91
# Name: Course Subject, dtype: int64

# %%
#To find the courses offered by each instructor

# %%
Course.groupby('Instructors')['Instructors'].count()
# Out:
# Instructors
# Aaron Bernstein, Jack Spengler                                                                               1
# Abhijit Vinayak Banerjee, Esther Duflo, Benjamin Olken                                                       1
# Adam Arkin, Ron Weiss                                                                                        1
# Alain Viel, Rachelle Gaudet                                                                                  1
# Alex Byrne                                                                                                   1
#                                                                                                             ..
# Tom Kelly                                                                                                    6
# Trudy Van Houten                                                                                             1
# ...

# %%
#To find the number of participants in each course

# %%
(Course[['Course Title','Participants']]).head(10)
# Out:
#                                         Course Title  Participants
# 0                           Circuits and Electronics         36105
# 1   Introduction to Computer Science and Programming         62709
# 2              Introduction to Solid State Chemistry         16663
# 3                   Introduction to Computer Science        129400
# 4  Health in Numbers: Quantitative Methods in Cli...         52521
# 5   Introduction to Computer Science and Programming         65380
# 6              Introduction to Solid State Chemistry          8270
# 7                   The Challenges of Global Poverty         29044
# 8                          Electricity and Magnetism         39178
# 9                                            Justice         58779

# %%
#To find the longest course available

# %%
Course[['Course Title','Total Course Hours']][Course['Total Course Hours']==max(Course['Total Course Hours'])]
# Out:
#                                          Course Title  Total Course Hours
# 153  Introduction to Computer Science and Programming              895.01

# %%
#To find the number of courses offered by each institutions

# %%
Course.groupby('Institution')['Institution'].count()
# Out:
# Institution
# HarvardX    129
# MITx        161
# Name: Institution, dtype: int64

# %%
#To find the course attended by the highest female percentage

# %%
Course[['Course Title','Instructors','Per Female']][Course['Per Female']==max(Course['Per Female'])]
# Out:
#                                        Course Title Instructors  Per Female
# 286  Introduction to Family Engagement in Education  Karen Mapp       74.76

# %%
#To find the course attended by the lowest female percentage

# %%
Course[['Course Title','Instructors','Per Female']][Course['Per Female']==min(Course['Per Female'])]
# Out:
#                             Course Title                  Instructors  \
# 288  Introduction to State Space Control  Jacob White, Joe Steinmeyer
#
#      Per Female
# 288        6.56

# %%
#To find the comparison between total hours and hours needed for certification.

# %%
(Course[['Course Title','Median Hours for Certification','Total Course Hours']]).head(10)
# Out:
#                                         Course Title  \
# 0                           Circuits and Electronics
# 1   Introduction to Computer Science and Programming
# 2              Introduction to Solid State Chemistry
# 3                   Introduction to Computer Science
# 4  Health in Numbers: Quantitative Methods in Cli...
# 5   Introduction to Computer Science and Programming
# 6              Introduction to Solid State Chemistry
# 7                   The Challenges of Global Poverty
# 8                          Electricity and Magnetism
# 9                                            Justice
#
#    Median Hours for Certification  Total Course Hours
# 0                           64.45              418.94
# 1                           78.53              884.04
# 2                           61.28              227.55
# 3                            0.00              220.90
# 4                           76.10              804.41
# ...

# %%
#To create a new column showing the difference between Total hours and median hours.

# %%
Course['Course hours']=Course['Total Course Hours']-Course['Median Hours for Certification']
Course.head()
# Out:
#   Institution Course Number          Launch Date  \
# 0        MITx        6.002x  2012-05-09 00:00:00
# 1        MITx         6.00x           09/26/2012
# 2        MITx        3.091x  2012-09-10 00:00:00
# 3    HarvardX         CS50x           10/15/2012
# 4    HarvardX        PH207x           10/15/2012
#
#                                         Course Title  \
# 0                           Circuits and Electronics
# 1   Introduction to Computer Science and Programming
# 2              Introduction to Solid State Chemistry
# 3                   Introduction to Computer Science
# 4  Health in Numbers: Quantitative Methods in Cli...
#
#                                          Instructors  \
# 0                                     Khurram Afridi
# 1            Eric Grimson, John Guttag, Chris Terman
# 2                                       Michael Cima
# 3  David Malan, Nate Hardison, Rob Bowden, Tommy ...
# 4                 Earl Francis Cook, Marcello Pagano
#
# ...

# %%
#To find the information about the courses in the increaing order of particpants

# %%
Course.sort_values('Participants').head(10)
# Out:
#     Institution Course Number          Launch Date  \
# 270        MITx    21W.789.5x           05/23/2016
# 268        MITx      3.054.3x  2016-11-05 00:00:00
# 207    HarvardX       SW12.7x  2015-02-11 00:00:00
# 208    HarvardX       SW12.8x  2015-02-11 00:00:00
# 201    HarvardX       SW12.4x           10/27/2015
# 202    HarvardX       SW12.5x           10/27/2015
# 187    HarvardX    GOV1368.3x  2015-01-10 00:00:00
# 256        MITx      3.054.2x  2016-08-04 00:00:00
# 188    HarvardX    GOV1368.4x  2015-01-10 00:00:00
# 209    HarvardX       SW12.9x  2015-02-11 00:00:00
#
#                                           Course Title  \
# 270  Mobile Application Experiences: Reporting Rese...
# 268            Cellular Solids: Applications in Nature
# 207  Invasions, Rebellions and the Fall of Imperial...
# 208       Creating Modern China: The Birth of a Nation
# 201  Literati China: Examinations and Neo-Confucianism
# 202  From a Global Empire under the Mongols to a Gl...
# ...

# %%
#To drop the course number column

# %%
Course.drop('Course Number',axis=1).head(10)
# Out:
#   Institution          Launch Date  \
# 0        MITx  2012-05-09 00:00:00
# 1        MITx           09/26/2012
# 2        MITx  2012-09-10 00:00:00
# 3    HarvardX           10/15/2012
# 4    HarvardX           10/15/2012
# 5        MITx  2013-04-02 00:00:00
# 6        MITx  2013-05-02 00:00:00
# 7        MITx  2013-12-02 00:00:00
# 8        MITx           02/18/2013
# 9    HarvardX  2013-02-03 00:00:00
#
#                                         Course Title  \
# 0                           Circuits and Electronics
# 1   Introduction to Computer Science and Programming
# 2              Introduction to Solid State Chemistry
# 3                   Introduction to Computer Science
# 4  Health in Numbers: Quantitative Methods in Cli...
# 5   Introduction to Computer Science and Programming
# 6              Introduction to Solid State Chemistry
# 7                   The Challenges of Global Poverty
# 8                          Electricity and Magnetism
# ...

# %% [markdown]
# # Visualizing dataset

# %%
#To find the average particpants per course

# %%
sns.barplot(x='Course Subject',y='Participants',data=Course)
plt.title('Average Participants per Course Title',size=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
#To find the percentage of males attending each course

# %%
sns.barplot(x='Course Title',y='Per Male',data=Course.head())
plt.title('Percentage male attendence per Course subject',size=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
#To find the number of courses offered by each institute

# %%
sns.set_theme(style='dark')
sns.countplot(x='Institution',data=Course,color='red')
plt.title('Number of courses per Institute',size=15)
plt.ylabel('Number of courses')
plt.show()

# %%
#To find average participants per subject

# %%
Pie=Course.groupby('Course Subject')['Participants'].mean()
Pie.plot.pie(autopct="%.1f%%")
plt.title('Average participants per subject',size=15)
plt.show()

# %%
#To find total course hours per subject

# %%
sns.lineplot(x='Course Title',y='Total Course Hours',data=Course.head(10))
plt.xticks(rotation='vertical')
plt.title('Total course hours per subject',size=15)
plt.show()
